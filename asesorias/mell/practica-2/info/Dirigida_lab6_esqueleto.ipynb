# %% [markdown]
# ## Carga de librerías básicas
# Su instalación no es necesaria ya que se encuentran preconfiguradas en el entorno de trabajo de Google Colab

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns # librería que extiende las funcionalidades de matplotlib

# %%
df = pd.read_csv('data_dirigida.csv')
df

# %% [markdown]
# ### a) Seleccione todos los registros ocurridos antes del día 3 o luego del día 57 y muéstrelos. ¿Cuántos son?

# %% [markdown]
# ### b) Obtenga una estadística de frecuencias sobre la variable categórica "Categoria" de df_compras

# %% [markdown]
# ### c) Por cada categoría de entrada, obtener la media, la desviación estándar y el total de dinero gastado en compras ¿Cuál es la más cara, en promedio?

# %% [markdown]
# ### d) Obtenga la misma información del inciso c), pero considerando únicamente a las categorías "1_Normal" y "2_Especial" y los días mayores a 20.
# *Sugerencia*: Utilice el método `df.column.isin(values)` de la librería pandas.

# %% [markdown]
# ### e) Cree un diccionario que almacene:
#
# - Clientes 1, 5 y 10 bajo la llave "clientes_bajo_valor"
# - Clientes 3000, 3300 y 3600 bajo la llave "clientes_alto_valor"
#
# Utilícelo para calcular el dinero total gastado en compras de cada grupo
#
# *Sugerencia*: Utilice el método `df.column.isin(values)` de la librería pandas.

# %% [markdown]
# ### f) Utilice un gráfico de dispersión para estudiar el comportamiento de los precios de entrada a través de los días. Haga una distinción por categoría y comente sobre los patrones observados
#
# *Sugerencia 1*: Utilice la función "sns.scatterplot()" de la librería seaborn
#
# *Sugerencia 2*: Si la gráfica se ve muy pequeña, pruebe ejecutar el comando "plt.figure(figsize=(10,6))" en la primera línea de la celda. Puede probar modificar los valores de `figsize` para visualizar su efecto

# %% [markdown]
# ### g) Cree un grafico de cajas (boxplot) para el precio de entrada por categoría

# %% [markdown]
# ### h) Cree un histograma para el precio de entrada por categoría.

# %% [markdown]
# ### i) Cree un diagrama de barras para evaluar la frecuencia por categoría.
